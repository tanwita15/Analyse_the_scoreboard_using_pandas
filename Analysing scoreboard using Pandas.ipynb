# %%
import pandas as pd
import numpy as np

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\User'

# %%
os.chdir("C:\Users\User\Downloads\Notebooks\Lesson_10_Practices\Data Operations in Pandas Dataframe-Unassisted Practice\Pandas-results.csv")
# Out:
#   Cell In[13], line 1
#     os.chdir("C:\Users\User\Downloads\Notebooks\Lesson_10_Practices\Data Operations in Pandas Dataframe-Unassisted Practice\Pandas-results.csv")
#                                                                                                                                                ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
data=pd.read_csv(r"C:\Users\User\Downloads\Notebooks\Lesson_10_Practices\Data Operations in Pandas Dataframe-Unassisted Practice\Pandas-results.csv")

# %%
data
# Out:
#              date         home_team        away_team  home_score  away_score  \
# 0      1872-11-30          Scotland          England           0           0
# 1      1873-03-08           England         Scotland           4           2
# 2      1874-03-07          Scotland          England           2           1
# 3      1875-03-06           England         Scotland           2           2
# 4      1876-03-04          Scotland          England           3           0
# ...           ...               ...              ...         ...         ...
# 40834  2019-07-18    American Samoa           Tahiti           8           1
# 40835  2019-07-18              Fiji  Solomon Islands           4           4
# 40836  2019-07-19           Senegal          Algeria           0           1
# 40837  2019-07-19        Tajikistan      North Korea           0           1
# 40838  2019-07-20  Papua New Guinea             Fiji           1           1
#
# ...

# %%
df=pd.DataFrame(home_team)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_36880\1044689345.py in ?()
# ----> 1 df=pd.DataFrame('home_team')
#
# ~\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, data, index, columns, dtype, copy)
#     813                 )
#     814         # For data is scalar
#     815         else:
#     816             if index is None or columns is None:
# --> 817                 raise ValueError("DataFrame constructor not properly called!")
#     818
#     819             index = ensure_index(index)
#     820             columns = ensure_index(columns)
#
# ValueError: DataFrame constructor not properly called!

# %%
data[['home_team','home_score']];

# %%
data
# Out:
#              date         home_team        away_team  home_score  away_score  \
# 0      1872-11-30          Scotland          England           0           0
# 1      1873-03-08           England         Scotland           4           2
# 2      1874-03-07          Scotland          England           2           1
# 3      1875-03-06           England         Scotland           2           2
# 4      1876-03-04          Scotland          England           3           0
# ...           ...               ...              ...         ...         ...
# 40834  2019-07-18    American Samoa           Tahiti           8           1
# 40835  2019-07-18              Fiji  Solomon Islands           4           4
# 40836  2019-07-19           Senegal          Algeria           0           1
# 40837  2019-07-19        Tajikistan      North Korea           0           1
# 40838  2019-07-20  Papua New Guinea             Fiji           1           1
#
# ...

# %%
sort_df = df.sort_values('home_score')
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 sort_df = df.sort_values('home_score')
#       2 df
#
# NameError: name 'df' is not defined

# %%
data
# Out:
#              date         home_team        away_team  home_score  away_score  \
# 0      1872-11-30          Scotland          England           0           0
# 1      1873-03-08           England         Scotland           4           2
# 2      1874-03-07          Scotland          England           2           1
# 3      1875-03-06           England         Scotland           2           2
# 4      1876-03-04          Scotland          England           3           0
# ...           ...               ...              ...         ...         ...
# 40834  2019-07-18    American Samoa           Tahiti           8           1
# 40835  2019-07-18              Fiji  Solomon Islands           4           4
# 40836  2019-07-19           Senegal          Algeria           0           1
# 40837  2019-07-19        Tajikistan      North Korea           0           1
# 40838  2019-07-20  Papua New Guinea             Fiji           1           1
#
# ...

# %%
data[['home_team','home_score']]
# Out:
#               home_team  home_score
# 0              Scotland           0
# 1               England           4
# 2              Scotland           2
# 3               England           2
# 4              Scotland           3
# ...                 ...         ...
# 40834    American Samoa           8
# 40835              Fiji           4
# 40836           Senegal           0
# 40837        Tajikistan           0
# 40838  Papua New Guinea           1
#
# [40839 rows x 2 columns]

# %%
#finding the home team with maximum home score
sort_data=data.sort_values('home_score')
print("Maximum home goals:",data['home_score'].max())
data.loc[data['home_score']==31]
# Out:
# Maximum home goals: 31
#              date  home_team       away_team  home_score  away_score  \
# 23781  2001-04-11  Australia  American Samoa          31           0
#
#                          tournament           city    country  neutral
# 23781  FIFA World Cup qualification  Coffs Harbour  Australia    False

# %%
#printing the teams with home score greater than 0
print(data[data['home_score']>0])
# Out:
#              date         home_team        away_team  home_score  away_score  \
# 1      1873-03-08           England         Scotland           4           2
# 2      1874-03-07          Scotland          England           2           1
# 3      1875-03-06           England         Scotland           2           2
# 4      1876-03-04          Scotland          England           3           0
# 5      1876-03-25          Scotland            Wales           4           0
# ...           ...               ...              ...         ...         ...
# 40831  2019-07-18  Papua New Guinea            Tonga           8           0
# 40833  2019-07-18     New Caledonia           Tuvalu          11           0
# 40834  2019-07-18    American Samoa           Tahiti           8           1
# 40835  2019-07-18              Fiji  Solomon Islands           4           4
# 40838  2019-07-20  Papua New Guinea             Fiji           1           1
#
# ...

# %%
#filtering the data with home score greater than 0
dfx = data[data['home_score']>0]
dfx['winner']=np.where((dfx['home_score']>dfx['away_score']),dfx['home_team'],dfx['away_team'])
dfx
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_36880\2636747009.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfx['winner']=np.where((dfx['home_score']>dfx['away_score']),dfx['home_team'],dfx['away_team'])
#              date         home_team        away_team  home_score  away_score  \
# 1      1873-03-08           England         Scotland           4           2
# 2      1874-03-07          Scotland          England           2           1
# 3      1875-03-06           England         Scotland           2           2
# 4      1876-03-04          Scotland          England           3           0
# 5      1876-03-25          Scotland            Wales           4           0
# ...
